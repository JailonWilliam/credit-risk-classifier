# %% [markdown]
# ## 1. Escolha do Problema e da base de dados

# %% [markdown]
# ### Objetivo do trabalho

# %% [markdown]
# O objetivo do trabalho é aplicar técnicas e algoritmos de Aprendizado de Máquina para resolver um problema real. Nesse sentido, selecionamos uma base de dados de risco de créditos com o intuito de realizar previsões sobre quais usuários irão pagar o empréstimo e quais não irão.

# %% [markdown]
# ### Link da base de dados

# %% [markdown]
# Link de acesso: https://www.kaggle.com/datasets/laotse/credit-risk-dataset

# %% [markdown]
# ### Informações sobre a base de dados credit_risk_dataset

# %% [markdown]
# O Dataframe possui as seguintes características:
# 1. Conteúdo das Colunas:
#    - **person_age:** Idade da pessoa (type: inteiro).
#    - **person_income:** Renda da pessoa (type: inteiro).
#    - **person_home_ownership:** Tipo de moradia da pessoa (type: string).
#    - **person_emp_length:** Tempo (em anos) que a pessoa está empregada (type: float).
#    - **loan_intent:** Finalidade do empréstimo (type: string).
#    - **loan_grade:** Classificação do empréstimo realizada pelo credor (type: string).
#    - **loan_amnt:** Valor do empréstimo (type: inteiro).
#    - **loan_int_rate:** Taxa de juros aplicada no empréstimo (type: foat).
#    - **loan_status:** Status do empréstimo: 1 é inadimplência, 0 caso o contrário (type: inteiro).
#    - **loan_percent_income:** Percentual da renda (type: float).
#    - **cb_person_default_on_file:** Indica se a pessoa tem histórico de inadiplência, Y para sim, N caso o contrário (type: string).
#    - **cb_person_cred_hist_length:** Duração do histórico de crédito (type: inteiro).
# 2. Tipos de variáveis das colunas:
#    - **person_age:** Discreta (idade representada por números inteiros).
#    - **person_income:** Contínua (renda representada por números reais).
#    - **person_home_ownership:** Nominal (não possui ordem específica).
#    - **person_emp_length:**  Discreta.
#    - **loan_intent:** Nominal (não possui ordem específica).
#    - **loan_grade:** Ordinal (classificação de crédito).
#    - **loan_amnt:** Contínua (valor do empréstimo é representada por números reais).
#    - **loan_int_rate:** Contínua (taxa de juros é representada por números reais).
#    - **loan_status:** Discreta.
#    - **loan_percent_income:** Contínua (porcentagem do valor pode ser representada por números reais).
#    - **cb_person_default_on_file:**  Nominal (não possui ordem específica).
#    - **cb_person_cred_hist_length:** Discreta (anos podem ser ordenados).
#
# Note que para determinar o tipo de variável da coluna, estamos levando em conta que ela pode ser:
# - Numérica
#    - **Contínua:** Números reais. Ex: Temperatura, altura, peso e salário.
#    - **Discreta:** Conjunto de valores finitos (inteiros).
# - Categórica
#    - **Nominal:** Dados não mensuráveis. Ex: Cor dos olhos e gênero.
#    - **Ordinal:** Categorização sob uma ordenação. Ex: Tamanho de blusa P, M e G.

# %% [markdown]
# ## 2. Pré-processamento de dados

# %% [markdown]
# ### Importações das bibliotecas para o funcionamento do código:

# %% [markdown]
# 1. **pandas**
#    - Manipulação e análise de dados de DataFrame.
# 2. **Numpy**
#    - Biblioteca para computação numérica. Fornece suporte para arrays multidimensionais eficientes e funções matemáticas.
# 3. **matplotlib.pyplot**
#    - Subbiblioteca do Matplotlib. Fornece uma interface semalhante ao MATLAB para criar gráficos estáticos.
# 4. **plotly**
#    - Criação e visualização interativa de dados.
# 5. **seaborn**
#    - Visualização de dados baseada no Matplotlib. Auxilia na criação de gráficos estátiscos.
# 6. **sklearn**
#    - Biblioteca para aprendizado de máquina, ou seja, fornece várias ferramenteas para tarefas de aprendizado de máquina, por exemplo, classificação, regressão e agrupamento.
# 7. **yellowbrick**
#    - Biblioteca que auxilia na visualização de dados e no diagnóstico de modelos de aprendizado de máquina.
#
# **OBS:** Talvez seja necessário atualizar o nbformart para a visualização dos gráficos dinâmicos.
# - pip install --upgrade nbformat

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Carregando o DataFrame

# %%
df = pd.read_csv("credit_risk_dataset.csv") # Utilizando a função read_csv do pandas para carregar o csv

# %%
df_2 = df.copy() # Realizando uma cópia

# %% [markdown]
# ### Exploração dos dados

# %%
df_2.head() # Analisando o começo do DataFrame
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# ...

# %%
df_2.tail() # Analisando o fim do DataFrame
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# ...

# %%
df_2.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# ...

# %% [markdown]
# Na célula acima, estamos analisando os dados estatísticos de cada coluna da nossa base de dados. Utilizando a função ***describe***, é possível obter para todas as colunas:
# - **count:** Quantidade de registros.
# - **mean:** Média dos valores dos registros.
# - **std:** Desvio padrão.
# - **min:** Menor valor do registro.
# - **25%:** Primeiro quartil.
# - **50%:** Segundo quartil (mediana).
# - **75%:** Terceiro quartil.
# - **max:** Maior valor do registro.
#
# **OBS:** Com esses dados obtidos, na seção seguinte iremos complementar com um apoio visual, isto é, iremos gerar alguns gráficos para dar suporte visual a nossa análise.

# %%
df_2["person_income"].mean() # Calculando a média da renda pessoal
# Out:
# 66074.84846996715

# %%
df_2[df_2["person_income"] >= 6000000] # Analisando a maior renda pessoal
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32297         144        6000000              MORTGAGE               12.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 32297    PERSONAL          C       5000          12.73            0
#
#        loan_percent_income cb_person_default_on_file  \
# 32297                  0.0                         N
#
#        cb_person_cred_hist_length
# 32297                          25

# %%
df_2[df_2["person_income"] <= 4000] # Analisando a pessoa com a menor renda pessoal
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 31930          41           4000                  RENT                0.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 31930     MEDICAL          C       2000          13.22            1
#
#        loan_percent_income cb_person_default_on_file  \
# 31930                  0.5                         Y
#
#        cb_person_cred_hist_length
# 31930                          15

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
# Note que a coluna ***person_emp_length*** e ***loan_int_rate*** possuem campos vazios, ou seja, existem valores nulos nessas colunas. Futuramente, iremos tratar isso!

# %% [markdown]
# ### Visualização de dados

# %% [markdown]
# #### Informações sobre essa seção

# %% [markdown]
# 1. Para a visualização dos dados, foram utilizadas as seguintes funções:
# - **np.unique():** retorna as variáveis presentes na coluna e a quantidade.
# - **sns.counplot():** cria um gráfico de barras para contar o valor de ocorrências.
# - **plt.hist():** cria um histograma.
# - **px.scatter_matrix():** cria uma matriz de gráfico de dispersão.
#
# 2. Dados importantes observados através dos gráficos:
# - Existe uma grande diferença na quantidade de pessoas que pagaram as dívidas e as que não pagaram.
# - Idades extremamente altas. (exemplo: 144 anos)
# - Existem muitos clientes jovens entre 20 a 30 anos.
# - A maioria dos clientes possuem entre 0 a 1M de renda pessoal.
# - Existem pessoas que estão trabalhando a mais de 60 anos.
#
# **OBS:** Alguns Histogramas, por terem poucas pessoas em um determinado setor, não é possível ver a barra. Entretanto, ela existe e os dados estão presentes em outros gráficos que acompanham eles!

# %% [markdown]
# ##### Visualização da quantidade de pessoas que pagam o empréstimo

# %%
# Utilizado o ponto e vírgula no final para retornar apenas o gráfico.
sns.countplot(x = df_2["loan_status"]);

# Descrição
plt.xlabel('0 - não inadimplência (pagamento em dia); 1 - inadimplência (pagamento não realizado).')
plt.ylabel('Contagem')
plt.title('Contagem de inadimplência')
plt.show()

# %% [markdown]
# ##### Visualização da quantidade de anos que a pessoa trabalha

# %%
grafico = px.scatter_matrix(df_2["person_emp_length"])

# Descrição
grafico.update_layout(
    title="Matriz de Dispersão - Tempo empregado",
    title_font_size=20
)

grafico.show()

# %% [markdown]
# **Nota:** existem pessoas empregas há 123 anos!

# %% [markdown]
# ##### Visualização do histórico de inadimplência

# %%
np.unique(df_2["cb_person_default_on_file"], return_counts=True)
# Out:
# (array(['N', 'Y'], dtype=object), array([26836,  5745], dtype=int64))

# %%
# Utilizado o ponto e vírgula no final para retornar apenas o gráfico.
sns.countplot(x = df_2["cb_person_default_on_file"]);

# Descrição
plt.xlabel('Histórico de Inadimplência')
plt.ylabel('Contagem')
plt.title('Contagem do Histórico de Inadimplência')
plt.show()

# %% [markdown]
# **Nota:** o gráfico apresenta uma grande diferença entre as pessoas que possuem inadimplência no histórico e as que não possuem.

# %% [markdown]
# #### Visualização das idades

# %%
grafico = px.scatter_matrix(df_2["person_age"])

# Descrição
grafico.update_layout(
    title="Matriz de Dispersão - Idades",
    title_font_size=20
)

# %% [markdown]
# **Nota:** existem pessoas com idades extremamente altas, por exemplo, 144 anos!!!

# %%
plt.hist(x = df_2["person_age"], bins=20, color='blue', alpha=0.8);

# Descrição
plt.xlabel('Idade')
plt.ylabel('Contagem')
plt.title('Distribuição de Idade')
plt.show()

# %% [markdown]
# **Nota:** Existem uma concentração significativa entre cliente jovens, com idades de 20 a 30 anos. Essa faixa etária apresenta uma contagem extremamente maior, se comparada as outras idades.
#
# **OBS:** É importante ressaltar que essa conclusão foi com base na análise visual do histograma e na identificação de região com maior frequência.

# %%
sns.boxplot(x = df_2["person_age"], color='blue');

# Descrição
plt.title("Distribuição de Idade")
plt.xlabel("Idade")
plt.show()

# %% [markdown]
# #### Visualização da renda pessoal

# %%
grafico = px.scatter_matrix(df_2["person_income"])

# Descrição
grafico.update_layout(
    title="Matriz de Dispersão - Renda pessoal",
    title_font_size=20
)

grafico.show()

# %%
plt.hist(x = df_2["person_income"], bins=20, color='blue', alpha=0.8)

# Descrição
plt.xlabel('Renda Pessoal')
plt.ylabel('Contagem')
plt.title('Distribuição de Renda Pessoal')
plt.show()

# %% [markdown]
# **Nota:** A maioria dos clientes possuem uma renda pessoal na faixa de 0 a 700k. Essa faixa apresenta uma contagem maior em relação as outras.
#
# **OBS:** É importante ressaltar que essa conclusão foi com base na análise visual do histograma e na identificação de região com maior frequência.

# %% [markdown]
# #### Visualização do valor do empréstimo

# %%
plt.hist(x = df_2["loan_amnt"], bins=20, color='blue', alpha=0.8);

# Descrição
plt.xlabel('Valor do Empréstimo')
plt.ylabel('Contagem')
plt.title('Distribuição do Valor do Empréstimo')
plt.show()

# %% [markdown]
# **Nota:** A maioria das pessoas tendem a pegar emprestado valores em torno de 5000 a 10000 unidade monetária. Sendo que esses valores correspondem aos picos mais altos do nosso histograma.
#
# **OBS:** É importante ressaltar que essa conclusão foi com base na análise visual do histograma e na identificação de região com maior frequência.

# %% [markdown]
# #### Visualização da idade, renda pessoal e valor do empréstimo em uma matriz de gráfico de dispersão

# %%
grafico = px.scatter_matrix(df_2, dimensions=["person_age", "person_income", "loan_amnt"], color="cb_person_default_on_file", color_discrete_sequence=["yellow", "blue"])

# Descrição
grafico.update_layout(
    title="Matriz de Dispersão - Idade, Renda pessoal e Valor do empréstimo",
    title_font_size=20
)

grafico.show()

# %% [markdown]
# ### Tratamento de valores duplicados

# %% [markdown]
# Nessa seção, iremos ver que ao realizar a contagem de valores duplicados na base de dados, foram encontrados 165 ocorrências. Portanto, procederemos com a remoção das mesmas.
#
# Funções utilizadas para realizar o procedimento:
# - **duplicated():** Retorna a linha que está duplicada, ou seja, ele retorna a linha B se ela for igual a linha A.
# - **drop_duplicated():** Remove as linhas duplicadas.
# - **sum():** Retorna uma soma. Nesse caso, foi utilizada para contar a quantidade de linhas duplicadas.

# %%
df_2.duplicated().sum()
# Out:
# 165

# %%
df_2.loc[df_2.duplicated()]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 15975          23          42000                  RENT                5.0
# 15989          23          90000              MORTGAGE                7.0
# 15995          24          48000              MORTGAGE                4.0
# 16025          24          10000                  RENT                8.0
# 16028          23         100000              MORTGAGE                7.0
# ...           ...            ...                   ...                ...
# 32010          42          39996              MORTGAGE                2.0
# 32047          36         250000                  RENT                2.0
# 32172          49         120000              MORTGAGE               12.0
# 32259          39          40000                   OWN                4.0
# 32279          43          11340                  RENT                4.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
df_2.drop_duplicates(inplace=True)

# %%
df_2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Tratamento de valores inconsistentes

# %% [markdown]
# Removendo idades extremamente altas, ou seja, aquelas maiores que 100 anos e removendo pessoas empregadas a mais de 60 anos.
#
# Existem alguns motivos para isso:
# - **Inconsistência de dados:** Estamos considerando que essas idades são inconsistências nessa base de dados, devido a erros ou problemas nesses registros.
# - **Anomalia:** É bastante incomum ter pessoas com idades extremamente altas, o que aumenta as suspeitas de erros nos dados.
# - **Impácto negligível:** Como o número de registros de idades extremamente altas é pequeno em relação ao tamanho total da nossa base de dados, não afetará significamente nossa análise de dados, sendo irrelevante.
#
# Para realizar a remoção, vamos seguir os seguintes passos:
# - Identificar as linhas que contém **idades maiores que 100 anos**, utilizando a função ***loc*** em conjunto de uma condicional para filtrar os dados e pegar o index dessas linhas com a função ***index***.
# - Identificar as linhas que contém pessoas **empregadas a mais de 60 anos**, utilizando a função ***loc*** em conjunto de uma condicional para filtrar os dados e pegar o index dessas linhas com a função ***index***.
# - Utilizar a função ***drop*** para remover as linhas identificadas.
# - Atualizar nossa base de dados ao dropar as linhas, utilizando ***inplace=True***.

# %%
df_2.loc[df_2["person_age"] > 100]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 81            144         250000                  RENT                4.0
# 183           144         200000              MORTGAGE                4.0
# 575           123          80004                  RENT                2.0
# 747           123          78000                  RENT                7.0
# 32297         144        6000000              MORTGAGE               12.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 81        VENTURE          C       4800          13.57            0
# 183     EDUCATION          B       6000          11.86            0
# 575     EDUCATION          B      20400          10.25            0
# 747       VENTURE          B      20000            NaN            0
# 32297    PERSONAL          C       5000          12.73            0
#
#        loan_percent_income cb_person_default_on_file  \
# 81                    0.02                         N
# ...

# %%
df_2.loc[df_2["person_emp_length"] > 60]
# Out:
#      person_age  person_income person_home_ownership  person_emp_length  \
# 0            22          59000                  RENT              123.0
# 210          21         192000              MORTGAGE              123.0
#
#     loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0      PERSONAL          D      35000          16.02            1
# 210     VENTURE          A      20000           6.54            0
#
#      loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                   0.59                         Y                           3
# 210                 0.10                         N                           4

# %%
df_2.shape
# Out:
# (32416, 12)

# %%
df_2.drop(df_2.loc[df_2["person_age"] > 100].index, inplace=True)

# %%
df_2.drop(df_2.loc[df_2["person_emp_length"] > 60].index, inplace=True)

# %%
df_2.shape
# Out:
# (32409, 12)

# %% [markdown]
# ### Tratamento de valores faltantes

# %% [markdown]
# Agora iremos analisar se existem campos vazios em nossa base de dados. Utilizaremos algumas funções da biblioteca pandas para fazer a análise:
#
# - **isnull():** Retorna uma matriz contendo valores booleanos, indicando quais valores são nulos e quais não são.
# - **sum():** Utilizamos essa função para retornar um somatório dos valores nulos retornados pela função ***isnull***.
# - **fillna():** Essa função é utilizada para preencher os valores nulos com um determinado conteúdo.
# - **median():** Retorna a mediana. Utilizamos para adquirir a mediana dos anos e dos juros.
#
# No geral, analisamos a base de dados com o somatório dos valores nulos encontrados em cada coluna. A maioria das colunas não possuem valores faltantes, porém, as colunas ***person_emp_length*** e ***loan_int_rate*** possuem 895 e 3094 valores faltantes respectivamente.
#
# Passos para corrigir esse problema:
# 1. Para a coluna ***person_emp_length***, utilizaremos a função ***median*** para adquirir a mediana de anos de emprego da coluna. Em seguida, com a função ***fillna***, preencheremos os campos vazios com o valor dessa mediana.
# 2. Para a coluna ***loan_int_rate***, utilizaremos a mesma estratégia do passo 1. Com a função ***median*** iremos adquirir a mediana da taxa de juros e com a função ***fillna***, preencheremos os campos vazios com o valor dessa mediana.

# %%
df_2.isnull()
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 1           False          False                  False              False
# 2           False          False                  False              False
# 3           False          False                  False              False
# 4           False          False                  False              False
# 5           False          False                  False              False
# ...           ...            ...                    ...                ...
# 32576       False          False                  False              False
# 32577       False          False                  False              False
# 32578       False          False                  False              False
# 32579       False          False                  False              False
# 32580       False          False                  False              False
#
# ...

# %%
df_2.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              887
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3094
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %% [markdown]
# ##### Removendo valores nulos da coluna ***person_emp_length***

# %%
df_2.loc[df_2["person_emp_length"].isnull()]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 105            22          12600              MORTGAGE                NaN
# 222            24         185000              MORTGAGE                NaN
# 379            24          16800              MORTGAGE                NaN
# 407            25          52000                  RENT                NaN
# 408            22          17352              MORTGAGE                NaN
# ...           ...            ...                   ...                ...
# 32285          38          12000                   OWN                NaN
# 32328          51          18408                  RENT                NaN
# 32360          70          39996                  RENT                NaN
# 32453          56          32400                  RENT                NaN
# 32471          53          54000                  RENT                NaN
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
media_loan_int_rate = df_2["loan_int_rate"].median()
df_2["loan_int_rate"] = df_2["loan_int_rate"].fillna(media_loan_int_rate)

# %%
# Localizando as linhas da coluna person_emp_length que foram trocadas pela mediana
media_person_emp_length = df_2["person_emp_length"].median()
df_2.loc[df_2["person_emp_length"] == media_person_emp_length]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 3              23          65500                  RENT                4.0
# 13             26         108160                  RENT                4.0
# 22             22          65000                  RENT                4.0
# 38             25          75000                  RENT                4.0
# 41             24          12000                   OWN                4.0
# ...           ...            ...                   ...                ...
# 32525          54         120000              MORTGAGE                4.0
# 32545          60           9600                  RENT                4.0
# 32560          57          77385                  RENT                4.0
# 32574          52          65004                  RENT                4.0
# 32577          54         120000              MORTGAGE                4.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
# Verificando se a troca foi bem sucedida
df_2["person_emp_length"].isnull().sum()
# Out:
# 887

# %% [markdown]
# ##### Removendo valores nulos da tabela ***loan_int_rate***

# %% [markdown]
# Com as funções ***mean*** e ***fillna***, iremos preencher cada campo vazio com os valores da média dessa coluna.

# %%
df_2["loan_int_rate"].head(15)
# Out:
# 1     11.14
# 2     12.87
# 3     15.23
# 4     14.27
# 5      7.14
# 6     12.42
# 7     11.11
# 8      8.90
# 9     14.74
# 10    10.37
# 11     8.63
# 12     7.90
# 13    18.39
# 14     7.90
# 15    10.65
# Name: loan_int_rate, dtype: float64

# %%
df_2.loc[df_2["loan_int_rate"].isnull()]
# Out:
# Empty DataFrame
# Columns: [person_age, person_income, person_home_ownership, person_emp_length, loan_intent, loan_grade, loan_amnt, loan_int_rate, loan_status, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length]
# Index: []

# %%
media_loan_int_rate = df_2["loan_int_rate"].median()
df_2["loan_int_rate"] = df_2["loan_int_rate"].fillna(media_loan_int_rate)

# %%
# Localizando as linhas da coluna person_emp_length que foram trocadas pela mediana
df_2.loc[df_2["loan_int_rate"] == media_loan_int_rate]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 19             24          10800              MORTGAGE                8.0
# 39             23          71500                  RENT                3.0
# 50             24          78000                  RENT                4.0
# 57             23         277000                   OWN                3.0
# 59             24          12000                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32552          65          45900                  RENT                2.0
# 32553          54          20000                  RENT                2.0
# 32569          51          60000              MORTGAGE                1.0
# 32570          58          72000                  RENT                5.0
# 32578          65          76000                  RENT                3.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
# Verificando se a troca foi bem sucedida
df_2["person_emp_length"].isnull().sum()
# Out:
# 887

# %% [markdown]
# ### Analisando o mapa de calor após o tratamento dos dados

# %% [markdown]
# **Mapa de calor:**
#
# O mapa de calor é basicamente uma matriz de dados, com os dados mapeados em uma escala de cores (predefinidas) para fornecer um maior suporte visual na análise dos dados. É comumente utilizado para identificar padrões e relações entre atributos, sendo que a principal função dessa gráfico é destacar visualmente as variações nos valores da matriz.
#
# Cada célula da matriz é composta por retângulos coloridos, com os valores numéricos sendo mapeados em uma escala de cores. Em outras palavras, os valores próximos de 0 são as cores mais frias e os valores proximos de 1 são as cores mais quentes, destacando assim, áreas com valores altos ou áreas com valores baixos.
#
# **Matriz de correlações:**
#
# Como o nome sugere, é uma matriz que mostra as correlações entre pares de variáveis em uma base de dados. Utiliza a medida de correção de Pearson, medindo as relações linear entre as duas variáveis.
#
# Cada célula dessa matriz representa a correlação entre duas variáveis, sendo que seu valor varia entre -1 e 1. Quanto maior o valor, mais forte é a relação entre as variáveis.
#
# **Anotações sobre esses valores:**
# - **Valor 1:** indica a correlação perfeita.
# - **Valor -1:** indica uma correlação negativa perfeita.
# - **valor proximo de 0:** indica uma correlação fraca ou nula.
#
# **Novas funções utilizadas:**
# - **select_dtypes():** Utilizada para selecionar colunas de um DataFrame com base em seu tipo de dado.
# - **heatmap():** Utilizada para criar um gráfico de mapa de calor.
# - **corr():** calcula a matriz de correlações entre as colunas de um DataFrame.
# - **corrwith():** calcula a correlação entre as colunas do DataFrame com uma coluna específica.
# - **sort_values():** classifica os valores de uma variável Series em ordem. o Parâmetro ***asceding=False*** indica que a ordenção deve ser em ordem decrescente.

# %%
colunas_numericas = df_2.select_dtypes(include=np.number)
matrix_correlacao = colunas_numericas.corr()

sns.heatmap(matrix_correlacao, annot=True, vmin=-1, vmax=1, cmap='crest');

# %%
correlacoes_loan_status = colunas_numericas.corrwith(df_2["loan_status"])
correlacoes_loan_status.sort_values(ascending=False)
# Out:
# loan_status                   1.000000
# loan_percent_income           0.379580
# loan_int_rate                 0.320041
# loan_amnt                     0.105601
# cb_person_cred_hist_length   -0.016441
# person_age                   -0.021774
# person_emp_length            -0.086313
# person_income                -0.169262
# dtype: float64

# %% [markdown]
# #### Removendo as colunas com base no mapa de calor

# %%
df_3 = df_2.copy()

# %%
df_3.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
df_3.drop(columns=["person_income", "person_emp_length", "person_age", "cb_person_cred_hist_length"], inplace=True)

# %%
df_3.head()
# Out:
#   person_home_ownership loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 1                   OWN   EDUCATION          B       1000          11.14
# 2              MORTGAGE     MEDICAL          C       5500          12.87
# 3                  RENT     MEDICAL          C      35000          15.23
# 4                  RENT     MEDICAL          C      35000          14.27
# 5                   OWN     VENTURE          A       2500           7.14
#
#    loan_status  loan_percent_income cb_person_default_on_file
# 1            0                 0.10                         N
# 2            1                 0.57                         N
# 3            1                 0.53                         N
# 4            1                 0.55                         Y
# 5            1                 0.25                         N

# %% [markdown]
# ### Divisão entre previsores e classes

# %% [markdown]
# Faz-se necessário realizar a divisão entre previsores e classes. Utilizaremos duas variáveis, uma para armazenar somente os atributos previsores (Geralmente é associada a X) e outra para armazenar somente a classe (Geralmente é associada ao Y).
# 1. Variáveis:
#     - **X_credit:** Variável previsora.
#     - **Y_credit:** Variável classe.
# 2. Funções utilizadas:
#     - **iloc():** responsável por selecionar as colunas desejadas.
#     - **values():** responsável por converter os valores para arrays NumPy.

# %% [markdown]
# ##### Criando a variável X_credit

# %%
X_credit = df_3.iloc[:, [0, 1, 2, 3, 4, 6, 7]].values

# %%
X_credit
# Out:
# array([['OWN', 'EDUCATION', 'B', ..., 11.14, 0.1, 'N'],
#        ['MORTGAGE', 'MEDICAL', 'C', ..., 12.87, 0.57, 'N'],
#        ['RENT', 'MEDICAL', 'C', ..., 15.23, 0.53, 'N'],
#        ...,
#        ['RENT', 'HOMEIMPROVEMENT', 'B', ..., 10.99, 0.46, 'N'],
#        ['MORTGAGE', 'PERSONAL', 'B', ..., 11.48, 0.1, 'N'],
#        ['RENT', 'MEDICAL', 'B', ..., 9.99, 0.15, 'N']], dtype=object)

# %%
type(X_credit)
# Out:
# numpy.ndarray

# %% [markdown]
# ##### Criando a variável Y_credit

# %%
Y_credit = df_3.iloc[:, 5].values

# %%
Y_credit
# Out:
# array([0, 1, 1, ..., 1, 0, 0], dtype=int64)

# %% [markdown]
# ### Tratamento das variáveis categóricas

# %% [markdown]
# O tratamento das variáveis categóricas é fundamental, pois os algoritmos de Machine Learning precisam processar adequadamente os dados, visto que os mesmos utilizam várias operações matemáticas. Então, para prosseguirmos, faz-se necessário realizar a conversão desses dados categóricos para dados numéricos, ou seja, iremos transformar strings em números.
#
# Para realizar esse processo, utilizaremos o LabelEnconder:
# - **LabelEnconder:** realiza um procedimento de mapeamento, associando cada valor categórico para um único número.
#
# **Funções utilizadas:**
# - **LabelEncoder.**
# - **fit_transform:** utilizado para aplicar transformações nos dados, como normalização e codificações de variáveis categóricas.

# %% [markdown]
# #### LabelEncoder

# %% [markdown]
# - Colunas de X_credit:
#     - **loan_grade:** Ordinal.
#     - **person_home_ownership:** Nominal.
#     - **loan_intent:** Nominal.
#     - **cb_person_default_on_file:** Nominal.

# %%
df_3.head()
# Out:
#   person_home_ownership loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 1                   OWN   EDUCATION          B       1000          11.14
# 2              MORTGAGE     MEDICAL          C       5500          12.87
# 3                  RENT     MEDICAL          C      35000          15.23
# 4                  RENT     MEDICAL          C      35000          14.27
# 5                   OWN     VENTURE          A       2500           7.14
#
#    loan_status  loan_percent_income cb_person_default_on_file
# 1            0                 0.10                         N
# 2            1                 0.57                         N
# 3            1                 0.53                         N
# 4            1                 0.55                         Y
# 5            1                 0.25                         N

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_enconder_loan_grade = LabelEncoder()                # Ordinal
label_enconder_person_home_ownership = LabelEncoder()     # Nominal
label_enconder_loan_intent = LabelEncoder()               # Nominal
label_enconder_cb_person_default_on_file = LabelEncoder() # Nominal

# %%
person_home_ownership = label_enconder_person_home_ownership.fit_transform(X_credit[:, 0])          # person_home_ownership
loan_intent = label_enconder_loan_intent.fit_transform(X_credit[:, 1])                              # loan_intent
loan_grade = label_enconder_loan_grade.fit_transform(X_credit[:, 2])                                # loan_grade
cb_person_default_on_file = label_enconder_cb_person_default_on_file.fit_transform(X_credit[:, 6])  # cb_person_default_on_file

# %%
loan_grade, person_home_ownership, loan_intent, cb_person_default_on_file
# Out:
# (array([1, 2, 2, ..., 1, 1, 1]),
#  array([2, 0, 3, ..., 3, 0, 3]),
#  array([1, 3, 3, ..., 2, 4, 3]),
#  array([0, 0, 0, ..., 0, 0, 0]))

# %%
X_credit[:, 0] = label_enconder_person_home_ownership.fit_transform(X_credit[:, 0])     # person_home_ownership
X_credit[:, 1] = label_enconder_loan_intent.fit_transform(X_credit[:, 1])               # loan_intent
X_credit[:, 2] = label_enconder_loan_grade.fit_transform(X_credit[:, 2])                # loan_grade
X_credit[:, 6] = label_enconder_cb_person_default_on_file.fit_transform(X_credit[:, 6]) # cb_person_default_on_file

# %%
X_credit[0] # Analisando a linha 0 da variável após o tratamento
# Out:
# array([2, 1, 1, 1000, 11.14, 0.1, 0], dtype=object)

# %% [markdown]
# ### Escalonamento de valores

# %% [markdown]
# Para lidar com o escalonamento dos valores na nossa base de dados, iremos utilizar a função ***StandardScaler*** da biblioteca ***sklearn.preprocessing***. Essa função permite que os valores possuam um tamanho comparável, fornecendo uma base melhor para o treinamento de modelos, pois existem algoritmos como o kNN (k-Nearest Neighbors) ou Neive Bayes que são influenciados pelo tamanho dos valores presentes nos atributos da base de dados.
#
# **Nova função utilizada:**
# - **StandardScalear:** Utilizado no pré-processamento para padronizar atributo por atributo, de modo que cada valor do atributo seja transformado de acordo com a média e o desvio padrão dos valores desse atributo. O cálculo feito é x = (x - média(x))/ Desvio_padrão(x).

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_credit
# Out:
# array([[2, 1, 1, ..., 11.14, 0.1, 0],
#        [0, 3, 2, ..., 12.87, 0.57, 0],
#        [3, 3, 2, ..., 15.23, 0.53, 0],
#        ...,
#        [3, 2, 1, ..., 10.99, 0.46, 0],
#        [0, 4, 1, ..., 11.48, 0.1, 0],
#        [3, 3, 1, ..., 9.99, 0.15, 0]], dtype=object)

# %%
standard_scaler_credit = StandardScaler()

# %%
X_credit = standard_scaler_credit.fit_transform(X_credit)

# %%
X_credit
# Out:
# array([[ 0.22528925, -0.88590655, -0.18886265, ...,  0.04070246,
#         -0.65785627, -0.46338983],
#        [-1.17023813,  0.26964234,  0.66779932, ...,  0.60183394,
#          3.74358002, -0.46338983],
#        [ 0.92305294,  0.26964234,  0.66779932, ...,  1.36730811,
#          3.3689897 , -0.46338983],
#        ...,
#        [ 0.92305294, -0.30813211, -0.18886265, ..., -0.00795056,
#          2.71345663, -0.46338983],
#        [-1.17023813,  0.84741678, -0.18886265, ...,  0.15098264,
#         -0.65785627, -0.46338983],
#        [ 0.92305294,  0.26964234, -0.18886265, ..., -0.33230402,
#         -0.18961836, -0.46338983]])

# %% [markdown]
# #### Seleção das bases de treinamento e teste

# %% [markdown]
# Nessa etapa, faz-se necessário realizar a divisão da base de dados em duas partes: uma para o processo de treinamento do algoritmo e outra para o teste, isto é, verificar a precisão que o algoritmo obteve ao tentar prever os atributos classes.
#
# **Novas funções utilizadas:**
# - **train_teste_split:** responsável por dividir a base de dados em treinamento e teste.
#     - Parâmetro **teste_size:** define a proporção dos dados que serão utilizados para teste.
#     - Parâmetro **random_state:** garante que a divisão dos dados seja possível. Se executar o código com o mesmo valor, obterá a mesma divisão de dados.

# %%
from sklearn.model_selection import train_test_split

# %%
X_credit_treinamento, X_credit_teste, Y_credit_treinamento, Y_credit_teste = train_test_split(X_credit, Y_credit, test_size=0.3, random_state=0)

# %%
X_credit_treinamento.shape, X_credit_teste.shape
# Out:
# ((22686, 7), (9723, 7))

# %%
Y_credit_treinamento.shape, Y_credit_teste.shape
# Out:
# ((22686,), (9723,))

# %% [markdown]
# Foram selecionados 22.686 registros para a base de dados de treinamento do X_credit! Já para o conjunto de teste, foram selecionados 9.723 registros. Esses registros serão utilizados para alimentar o nosso algoritmo. É importante ressaltar que a quantidade de registros para o treinamento e o teste do Y é exatamente a mesma.

# %% [markdown]
# #### Armazenando as variáveis em um arquivo .pkl

# %% [markdown]
# No final deste pré-processamento, é uma boa prática salvar as variáveis X_credit_treinamento, Y_credit_treinamento, X_credit_teste, Y_credit_teste em arquivos .pkl. Esse processo é importante para evitar ter que repetir toda etapa de pré-processamento novamente quando necessário utilizar esse conjunto de dados em etapas futuras.
#
# **bibliotecas/funções utilizadas:**
# - **pickle:** essa biblioteca é utilizada para salvar objetos python em arquivos.
# - **pickle.dump():** essa função serve para salvar objetos python em arquivos. Ela também consegue salvar objetos mais complexos como arrays, dicionários e modelos de Machine Learning.

# %%
import pickle

# %%
with open('credit.pkl', mode='wb') as file:
    pickle.dump([X_credit_treinamento, Y_credit_treinamento, X_credit_teste, Y_credit_teste], file)

# %% [markdown]
# ## 3. Aplicando o algoritmo Naive Bayes - 79,9% de acurácia

# %% [markdown]
# ### Explicação sobre o Algoritmo Naive Bayes

# %% [markdown]
# O algoritmo Naive Bayes é um classificador probabilístico simples, isto é, utiliza probabilidades condicionais para calcular a probabilidade de um exemplo pertencer a uma determinada classe. Por ele considerar que todos os atributos da base de dados são independentes entre si (o que geralmente não é verdade), permite realizar a aplicação em diversos cenários distintos.
#
# O processo de treinamento do Naive Bayes utiliza a base de dados de treinamento para estimar as probabilidades condicionais de cada classe. Quando treinado, o classificar consegue realizar previsões ao calcular as probabilidades condicionais de cada classe para novos exemplos, sendo que a classe escolhida será a que possuir a maior probabildade posterior, ou seja, probabilidade a posteriori.
#
# Por fim, o Naive Bayes utiliza como base o Teorema Bayes para realizar esses cálculos probabilísticos. Dado um exemplo, esse teorema usa a probabilidade a posteriori de uma classe, probabilidade a priori e as probabilidades condicionais dos atributos das classes.
#
# **Como é realizado o cálculo:**
# - P(Classe|Atributos) = (P(Atributos|Classe) * P(Classe)) / P(Atributos)
#     - P(Classe|Atributos): probabilidade a posteriori da classe.
#     - P(Atributos|Classe): probabilidade condicional do atributo dado a classe.
#     - P(Classe): probabilidade a priori da classe.
#     - P(Atributos): probabilidade dos atributos.
#
# 1. **Vantagens do Naive Bayes:**
#     - Rápido.
#     - Simplicidade de interpretação.
#     - Trabalha bem com vários atributos.
#     - Boas previsões em base de dados pequenas.
# 2. **Desvantagens do Naive Bayes:**
#     - Considera que todos os atributos da base de dados são independentes entre si. Na prática, isso nem sempre é verdade, por exemplo, não considerar que a renda pessoal tem relação com a dívida.
#
# **Novas funções utilizadas:**
# - **GaussianNB:** classificador do modelo Naive bayes.
# - **accuracy_score:** retorna a acurácia do modelo.
# - **confusion_matrix:** retorna a matriz de confusão do modelo.
# - **classification_report:** retorna dados mais detalhados do modelo, incluindo precisão, recall, f1-score e etc.

# %% [markdown]
# ### Implementação do algoritmo Naive bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from yellowbrick.classifier import ConfusionMatrix

# %% [markdown]
# #### Analisando dados com o Confusion matrix do sklearn

# %%
X_credit_treinamento.shape, Y_credit_treinamento.shape
# Out:
# ((22686, 7), (22686,))

# %%
Y_credit_treinamento.shape, Y_credit_teste.shape
# Out:
# ((22686,), (9723,))

# %%
naive_bayes = GaussianNB()
naive_bayes.fit(X_credit_treinamento, Y_credit_treinamento)
# Out:
# GaussianNB()

# %%
previsao_naive_bayes = naive_bayes.predict(X_credit_teste)

# %%
previsao_naive_bayes, Y_credit_teste # Precisamos comparar as duas
# Out:
# (array([1, 0, 0, ..., 0, 0, 1], dtype=int64),
#  array([0, 0, 0, ..., 0, 0, 1], dtype=int64))

# %% [markdown]
# **Nota:** Ao comprar esses 2 arrays e pegar a média de acerto, obtemos nossa acurácia.

# %%
accuracy_score(Y_credit_teste, previsao_naive_bayes)
# Out:
# 0.7998560115190785

# %%
confusion_matrix(Y_credit_teste, previsao_naive_bayes)
# Out:
# array([[6484, 1106],
#        [ 840, 1293]], dtype=int64)

# %%
print(classification_report(Y_credit_teste, previsao_naive_bayes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87      7590
#            1       0.54      0.61      0.57      2133
#
#     accuracy                           0.80      9723
#    macro avg       0.71      0.73      0.72      9723
# weighted avg       0.81      0.80      0.80      9723

# %% [markdown]
# **(naive_bayes)**
#
# **Nota:**
# - 0 indica se o cliente pagou o empréstimo.
# - 1 indica se o cliente não pagou o empréstimo.
#
# **Interpretação desses dados:**
# - **Clientes que pagam:** o modelo conseguiu identificar cerca de 85% dos clientes que pagaram o empréstimo, e quando ele identifica eles, tem a taxa de acerto de 89% (se de fato pagou ou não).
# - **Clientes que não pagam:** o modelo conseguiu identificar cerca de 61% dos clientes que não pagam o empréstimo e quando identifica eles, possui um taxa de acerto 54% (se de fato pagou ou não).

# %% [markdown]
# #### Analisando dados com o Confusion matrix do yellowbrick

# %%
naive_bayes = ConfusionMatrix(naive_bayes)
naive_bayes.fit(X_credit_treinamento, Y_credit_treinamento)
naive_bayes.score(X_credit_teste, Y_credit_teste)
# Out:
# 0.7998560115190785

# %% [markdown]
# **Interpretação desses dados:**
# - **Clientes que pagam:** Nosso modelo classificou 6484 clientes que pagam, como clientes que não pagam (ele acertou 6484). E classificou 1106 clientes que pagam, como clientes que não pagam. (ele errou 1106).
# - **Clientes que não pagam:** Nosso modelo classificou 1293 clientes não que pagam, como clientes que não pagam (ele acertou 1293). E classificou 840 clientes que pagam, como clientes que não pagam. (ele errou 840).

# %% [markdown]
# #### Utilizando a Validação cruzada: K-folder no Naive Bayes

# %% [markdown]
# A validação cruzada é uma técnica com uma avaliação mais completa do desempenho de um determinado modelo de machine learning. O intuito dela é estimar como o modelo se comporta com dados não vistos, o que permite uma avaliação mais completa de sua performace.
#
# Essa técnica usa como base a divisão do dataframe em K pedaços (também chamados de folds) de tamanhos iguais. O modelo então sofre uma interação K vezes, sendo que cada intereção, possui um fold atuando como teste e o restante como treinamento. A idéia é fazer esse procedimento, onde nunca irá acontecer de um fold ser utilizado como teste mais de uma vez, até acabar as interações.
#
# Por fim, após as K interações, adquirimos a média das métricas de avaliação, como precisão, acurácia e recall de cada fold para fazer uma análise geral do desempenho do nosso modelo.
#
# **Novas funções utilizadas:**
# - **cross_val_score:** Realiza a validação cruzada.
# - **KFold:** Realiza a divisão do conjunto de dados.

# %%
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.model_selection import KFold

# %%
kfold  = KFold(n_splits=10, shuffle=True, random_state=0) # Definindo o número de folds

# %%
arvore_decisao_validacao_cruzada = GaussianNB()

# %%
scores_naive_bayes = cross_val_score(arvore_decisao_validacao_cruzada, X_credit, Y_credit, cv=kfold)

# %%
scores_naive_bayes.mean()
# Out:
# 0.8001791094807654

# %% [markdown]
# **Nota:** Para conseguir a acurácia com a validação cruzada, temos que pegar a média!

# %%
# Comparando os 2, lado a lado
naive_bayes.score(X_credit_teste, Y_credit_teste), scores_naive_bayes.mean()
# Out:
# (0.7998560115190785, 0.8001791094807654)

# %% [markdown]
# **Nota:** Não houve uma mudança significativa.

# %%
print(classification_report(Y_credit_teste, previsao_naive_bayes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87      7590
#            1       0.54      0.61      0.57      2133
#
#     accuracy                           0.80      9723
#    macro avg       0.71      0.73      0.72      9723
# weighted avg       0.81      0.80      0.80      9723

# %% [markdown]
# **(naive_bayes)**
#
# **Nota:**
# - 0 indica se o cliente pagou o empréstimo.
# - 1 indica se o cliente não pagou o empréstimo.
#
# **Interpretação desses dados:**
# - **Clientes que pagam:** o modelo conseguiu identificar cerca de 85% dos clientes que pagaram o empréstimo, e quando ele identifica eles, tem a taxa de acerto de 89% (se de fato pagou ou não).
# - **Clientes que não pagam:** o modelo conseguiu identificar cerca de 61% dos clientes que não pagam o empréstimo e quando identifica eles, possui um taxa de acerto 54% (se de fato pagou ou não).

# %% [markdown]
# ## 4. Aplicando o algoritmo de Árvore de decisão - 86,5% de acurácia

# %% [markdown]
# A árvore de decisão é um algoritmo de machine learning utilizado para resolver problemas de classificação e regressão. Como o nome sugere, ela cria uma estrutura semelhante a uma árvore, sendo que são criados pontos de decisão (nó da árvore) e em cada um deles possui um resultado da decisão com um caminho (aresta da árvore). Com isso, temos que os nós da árvore são responsáveis por indicar um ramo a ser seguido, isto é, uma sequência de fluxo. Por fim, essa árvore pode ser construída seguindo critérios de Entropia e Índice GINI.
#
# Ademais, esse algoritmo também é a base do funcionamento de outros algoritmos, como o Random Forest, que foi criado para ser uma versão aprimorado da árvore de decisão.
#
# 1. **Entropia**
#     - Utiliza a varição da variável target para analisar a distribuição dos dados nas variáveis preditoras.
#     - O tamanho da entropia indica o tamanho da desordem dos dados, isto é, quando a análise é feita juntamente com a variável target.
#     - Com a entropia, o algoritmo confere a variável que possui o maior ganho de informação, pois essa variável será justamente a raiz da árvore.
# 2. **GINI**
#     - Assim como na entropia, utiliza a variação da variável target para analisar a distribuição dos dados nas variáveis preditoras. Entretanto, com um método diferente.
#     - A raiz da árvore será a variável preditora com o menor índice GINI, pois com o índice GINI, quanto menor for o valor, maior a ordem de distribuição dos dados.
#
# - **Vantagens:**
#     - Fácil de interpretar.
#     - Não precisa realizar o procedimento de normalização ou padronização dos dados.
#     - Rápido para classificar novos registros.
# - **Desvantagens:**
#     - Geração de árvores muito complexas.
#     - Pequenas variações nos dados pode alterar a árvore.
#     - Problemas NP-completo para construir a árvore.
#
# **Novas funções utilizadas:**
# - **DecisionTreeClassifier:** Classificador baseado em árvore de decisão.

# %% [markdown]
# ### Utilizando entropia como parâmetro para ganho de informação

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
with open('credit.pkl', mode='rb') as file:
    X_credit_treinamento, Y_credit_treinamento, X_credit_teste, Y_credit_teste = pickle.load(file)

# %%
X_credit_treinamento.shape, Y_credit_treinamento.shape
# Out:
# ((22686, 7), (22686,))

# %%
X_credit_teste.shape, Y_credit_teste.shape
# Out:
# ((9723, 7), (9723,))

# %%
arvore_decisao_entropy = DecisionTreeClassifier(criterion='entropy', random_state=0)
arvore_decisao_entropy.fit(X_credit_treinamento, Y_credit_treinamento)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
arvore_decisao_entropy.classes_
# Out:
# array([0, 1], dtype=int64)

# %%
previsao_arvore_decisao_entropy = arvore_decisao_entropy.predict(X_credit_teste)

# %%
Y_credit_teste, previsao_arvore_decisao_entropy
# Out:
# (array([0, 0, 0, ..., 0, 0, 1], dtype=int64),
#  array([0, 0, 0, ..., 0, 0, 1], dtype=int64))

# %% [markdown]
# **Nota:** Ao comparar esses 2 arrays e pegar a média de acerto, obtemos nossa acurácia.

# %%
accuracy_score(previsao_arvore_decisao_entropy, Y_credit_teste)
# Out:
# 0.8666049573177003

# %%
print(classification_report(Y_credit_teste, previsao_arvore_decisao_entropy))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91      7590
#            1       0.69      0.71      0.70      2133
#
#     accuracy                           0.87      9723
#    macro avg       0.80      0.81      0.81      9723
# weighted avg       0.87      0.87      0.87      9723

# %% [markdown]
# **(Árvore de decisão utilizando entropia como parâmetro para ganho de informação)**
#
# **Nota:**
# - 0 indica se o cliente pagou o empréstimo.
# - 1 indica se o cliente não pagou o empréstimo.
#
# **Interpretação desses dados:**
# - **Clientes que pagam:** o modelo conseguiu identificar cerca de 91% dos clientes que pagaram o empréstimo, e quando ele identifica eles, tem a taxa de acerto de 92% (se de fato pagou ou não).
# - **Clientes que não pagam:** o modelo conseguiu identificar cerca de 71% dos clientes que não pagam o empréstimo e quando identifica eles, possui um taxa de acerto 69% (se de fato pagou ou não).
# - **Acurácia do modelo:** 86,5%

# %%
mc_arvore_decisao_entropy = ConfusionMatrix(arvore_decisao_entropy)
mc_arvore_decisao_entropy.fit(X_credit_treinamento, Y_credit_treinamento)
mc_arvore_decisao_entropy.score(X_credit_teste, Y_credit_teste)
# Out:
# 0.8666049573177003

# %% [markdown]
# **Interpretação desses dados:**
# - **Clientes que pagam:** Nosso modelo classificou 6892 clientes que pagam, como clientes que não pagam (ele acertou 6892). E classificou 698 clientes que pagam, como clientes que não pagam (ele errou 698).
# - **Clientes que não pagam:** Nosso modelo classificou 1520 clientes não que pagam, como clientes que não pagam (ele acertou 1520). E classificou 613 clientes que pagam, como clientes que não pagam (ele errou 613).

# %% [markdown]
# ### Utilizando a Validação cruzada: K-folder na Árvore de decisão

# %%
kfold  = KFold(n_splits=10, shuffle=True) # Definindo o número de folds

# %%
arvore_decisao_validacao_cruzada = DecisionTreeClassifier(criterion='entropy') # Utilizando como critério para o ganho de informação, a entropia

# %%
scores_arvore_decisao = cross_val_score(arvore_decisao_validacao_cruzada, X_credit, Y_credit, cv=kfold)

# %%
scores_arvore_decisao.mean()
# Out:
# 0.8699741639716443

# %%
# Comparando os 2, lado a lado
mc_arvore_decisao_entropy.score(X_credit_teste, Y_credit_teste), scores_arvore_decisao.mean()
# Out:
# (0.8666049573177003, 0.8699741639716443)

# %% [markdown]
# **Nota:** ao utilizar a validação cruzada, nosso modelo conseguiu adquirir 0.87 de acurácia.

# %% [markdown]
# ### Utilizando índice GINI como parâmetro para ganho de informação

# %%
arvore_decisao_gini = DecisionTreeClassifier(criterion='gini', random_state=0)
arvore_decisao_gini.fit(X_credit_treinamento, Y_credit_treinamento)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
previsao_arvore_decisao_gini = arvore_decisao_gini.predict(X_credit_teste)

# %%
previsao_arvore_decisao_gini, Y_credit_teste
# Out:
# (array([0, 0, 0, ..., 0, 0, 1], dtype=int64),
#  array([0, 0, 0, ..., 0, 0, 1], dtype=int64))

# %% [markdown]
# **Nota:** Ao comparar esses 2 arrays e pegar a média de acerto, obtemos nossa acurácia.

# %%
accuracy_score(previsao_arvore_decisao_gini, Y_credit_teste)
# Out:
# 0.8684562377866913

# %%
print(classification_report(Y_credit_teste, previsao_arvore_decisao_gini))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92      7590
#            1       0.69      0.72      0.71      2133
#
#     accuracy                           0.87      9723
#    macro avg       0.81      0.82      0.81      9723
# weighted avg       0.87      0.87      0.87      9723

# %% [markdown]
# **(Árvore de decisão utilizando índice GINI como parâmetro para ganho de informação)**
#
#
# **Nota:**
# - 0 indica se o cliente pagou o empréstimo.
# - 1 indica se o cliente não pagou o empréstimo.
#
# **Interpretação desses dados:**
# - **Clientes que pagam:** o modelo conseguiu identificar cerca de 91% dos clientes que pagaram o empréstimo, e quando ele identifica eles, tem a taxa de acerto de 92% (se de fato pagou ou não).
# - **Clientes que não pagam:** o modelo conseguiu identificar cerca de 72% dos clientes que não pagam o empréstimo e quando identifica eles, possui um taxa de acerto 68% (se de fato pagou ou não).

# %%
mc_arvore_de_decisao_gini = ConfusionMatrix(arvore_decisao_gini)
mc_arvore_de_decisao_gini.fit(X_credit_treinamento, Y_credit_treinamento)
mc_arvore_de_decisao_gini.score(X_credit_teste, Y_credit_teste)
# Out:
# 0.8684562377866913

# %% [markdown]
# **Interpretação desses dados:**
# - **Clientes que pagam:** Nosso modelo classificou 6877 clientes que pagam, como clientes que não pagam (ele acertou 6877). E classificou 713 clientes que pagam, como clientes que não pagam (ele errou 713).
# - **Clientes que não pagam:** Nosso modelo classificou 1544 clientes não que pagam, como clientes que não pagam (ele acertou 1544). E classificou 589 clientes que pagam, como clientes que não pagam (ele errou 589).

# %% [markdown]
# ### Comparando a entropy com o índice GINI

# %% [markdown]
# De modo geral, o modelo que utilizou o Gini teve uma melhora no seu desempenho. Entretanto, não foi uma melhora significativa, ou seja, os 2 modelos para essas circustâncias, conseguiram performar bem.

# %%
mc_arvore_de_decisao_gini.score(X_credit_teste, Y_credit_teste)
# Out:
# 0.8684562377866913

# %%
mc_arvore_decisao_entropy.score(X_credit_teste, Y_credit_teste)
# Out:
# 0.8666049573177003

# %% [markdown]
# **Nota:** tivemos um aumento de 0.0009256 na acurácia ao utilizarmos o índice GINI como parâmetro de ganho de informação, isto é, ao compararmos o modelo feito com o GINI e o modelo feito com a entropia.

# %%
print(classification_report(Y_credit_teste, previsao_arvore_decisao_gini))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92      7590
#            1       0.69      0.72      0.71      2133
#
#     accuracy                           0.87      9723
#    macro avg       0.81      0.82      0.81      9723
# weighted avg       0.87      0.87      0.87      9723

# %%
print(classification_report(Y_credit_teste, previsao_arvore_decisao_entropy))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91      7590
#            1       0.69      0.71      0.70      2133
#
#     accuracy                           0.87      9723
#    macro avg       0.80      0.81      0.81      9723
# weighted avg       0.87      0.87      0.87      9723

# %% [markdown]
# **Nota:** Ao analisar esses dados, é possível notar que ao utilizarmos o índice GINI como parâmetro de ganho de informação, tivemos um aumento de 0.1 nos dados de precisão e recall que dizem respeito as pessoas que nãos pagam, isto é, ao comparmos o modelo feito com o GINI e o modelo feito com a entropia.

# %% [markdown]
# ## 5. Aplicando o algoritmo de Random Forest - 91,3% de acurácia

# %% [markdown]
# Como o nome sugere, esse algoritmo cria muitas árvores de decisão de forma aleatória, formando uma floresta. Cada árvore dessa floresta será utilizada na escolha do resultado final, sendo algo semelhante a uma votação. Dito isso, a ideia está voltada na combinação de diferentes modelos para conseguir um único resultado. O que torna o algoritmo mais completo e complexo, aumentando o custo computacional juntamente com melhores resultados.
#
# **Novas funções utilizadas:**
# - **RandomForestClassifier:** classificador do RandomForest
#     - **n_estimators:** número de árvores da floresta.
#     - **criterion:** define o parâmetro para a decisão do ganho de informação.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
with open('credit.pkl', mode='rb') as file:
    X_credit_treinamento, Y_credit_treinamento, X_credit_teste, Y_credit_teste = pickle.load(file)

# %%
random_forest = RandomForestClassifier(n_estimators=70, criterion='gini', random_state=0);
random_forest.fit(X_credit_treinamento, Y_credit_treinamento)
# Out:
# RandomForestClassifier(n_estimators=70, random_state=0)

# %%
previsao_random_forest = random_forest.predict(X_credit_teste)

# %%
previsao_random_forest, Y_credit_teste
# Out:
# (array([0, 0, 0, ..., 0, 0, 1], dtype=int64),
#  array([0, 0, 0, ..., 0, 0, 1], dtype=int64))

# %% [markdown]
# **Nota:** Ao comparar esses 2 arrays e pegar a média de acerto, obtemos nossa acurácia.

# %%
accuracy_score(Y_credit_teste, previsao_random_forest)
# Out:
# 0.9134012136171963

# %%
print(classification_report(previsao_random_forest, Y_credit_teste))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95      8062
#            1       0.69      0.89      0.78      1661
#
#     accuracy                           0.91      9723
#    macro avg       0.83      0.90      0.86      9723
# weighted avg       0.93      0.91      0.92      9723

# %% [markdown]
# **(RandomForst)**
#
#
# **Nota:**
# - 0 indica se o cliente pagou o empréstimo.
# - 1 indica se o cliente não pagou o empréstimo.
#
# **Interpretação desses dados:**
# - **Clientes que pagam:** o modelo conseguiu identificar cerca de 92% dos clientes que pagaram o empréstimo, e quando ele identifica eles, tem a taxa de acerto de 98% (se de fato pagou ou não).
# - **Clientes que não pagam:** o modelo conseguiu identificar cerca de 89% dos clientes que não pagam o empréstimo e quando identifica eles, possui um taxa de acerto 69% (se de fato pagou ou não).

# %%
mc_random_forest = ConfusionMatrix(random_forest)
mc_random_forest.fit(X_credit_treinamento, Y_credit_treinamento)
mc_random_forest.score(X_credit_teste, Y_credit_teste)
# Out:
# 0.9134012136171963

# %% [markdown]
# ## 6. Análise e discussão

# %% [markdown]
# **1. Naive Bayes:**
#
# - Classe 0:
#     - Precisão: 0,89
#     - Recall: 0,85
# - Classe 1:
#     - Precisão: 0,54
#     - Recall: 0,61
# - Acurácia do modelo: 0,80
#
# O Naive Bayes foi o modelo que apresentou um desempenho inferior se comparado com a Árvore de decisão e a Random forest, ele sai perdendo tanto em termo de precisão e recall, como em acurácia geral do modelo. O Random Forest foi o que mais se destacou, seguido pela Árvore de decisão e por fim o Naive Bayes.
#
# **2. Árvore de decisão:**
#
# - Classe 0:
#     - Precisão: 0,92
#     - Recall: 0,91
# - Classe 1:
#     - Precisão: 0,68
#     - Recall: 0,72
# - Acurácia do modelo: 0,87
#
# Note que para esse modelo, seus pontos fortes estão na alta precisão e recall para a class 0. Entretanto, a precisão e o recall para a class 1 são relativamente baixo em comparação ao Random Foreste. Uma alternativa para melhorar esse modelo, é ajustar os hiperparâmetros do modelo para tentar obter um desempenho melhor.
#
# **3. Random Forest:**
#
# - Classe 0:
#     - Precisão: 0,98
#     - Recall: 0,92
# - Classe 1:
#     - Precisão: 0,69
#     - Recall 1: 0,89
# - Acurácia do modelo: 0,91
#
# O Random Forest obteve os melhores resultados dos 3 algoritmos. Ele apresenta alta precisão e Recall tanto para a classe 0, como para a classe 1. Esse modelo conseguiu se adptar bem a um conjunto de dados desbalanceados (como vimos no pré-processamento).
#
# **Limitações e possíveis melhorias:**
# - Os modelos apresentam um desempenho baixo se compararmos a classe 0 com a classe 1, isso indica uma dificuldade em identificar de forma correta os falsos positivos. Note que isso é um problema para essa aplicação, visto que precisamos saber com mais precisão, justamente os clientes que não irão pagar os empréstimos.
# - Explorar técnicas de ajuste de hiperparâmetros, como GridSearch ou RandomSearch. Essa técnicas tem como objetivo analisar uma série de combinações para encontrar a melhor combinação de parâmetros para cada modelo.
#
# **Conclusão Geral:**
#
# Os três algoritmos de aprendizado de máquina foram capazes de conseguir resultados aceitáveis para o problema proposto, com acurácia de 80% a 91%. O modelo Random Forest teve uma performace melhor em relação aos demais, ele demonstrou ser bastante eficaz com essa base de dados em particular, sendo o modelo que teve a maior precisão, recall e acurácia. Entretanto, como foi citado acima, os algoritmos podem ser melhorados. Por fim, foi possível conseguir insights valiosos sobre o comportamento de diferentes modelos em uma base de dados desbalanceada, o que destaca a importância de ter conhecimento de várias técnicas e algoritmos para a escolha ideal para uma base de dados e para um problema.
